# %% [markdown]
# # Unsupervised ML (Clustering)

# %% [markdown]
# ## Assumption: You were given various crime datasets that contains all the DISTRICTS in each state and you were asked to provide the below data to the higher authorities for further action.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import  warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 4.1  Create 3 clusters as below.
# 1. Sensitive Area's
#
# 2. Moderate Area's
#
# 3. Peaceful Area's"

# %%
df=pd.read_csv("D:\\sahil\\01_District_wise_crimes_committed_IPC_2001_2012.csv")
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   YEAR                                                 9017 non-null   int64
#  3   MURDER                                               9017 non-null   int64
#  4   ATTEMPT TO MURDER                                    9017 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9017 non-null   int64
#  6   RAPE                                                 9017 non-null   int64
#  7   CUSTODIAL RAPE                                       9017 non-null   int64
# ...

# %% [markdown]
# From above we can see that there are no null values present as there are 9017 rows and every column has 9017 non null values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we can see there are no duplicated values

# %%
df.drop(df[df['DISTRICT'] == 'TOTAL'].index, inplace=True)
df.drop(df[df['DISTRICT'] == 'DELHI UT TOTAL'].index, inplace=True)

# %% [markdown]
# As we have worked on this dataset before we know that there were Total values in district column which shows sum total of every district for each state so we will remove those as we dont want to cluster them

# %% [markdown]
# ## Grouping the dataset according to the states/UT

# %%
df1 = df.groupby(['STATE/UT']).sum()
df1 = df1.drop(['YEAR'], axis=1)
df1= df1.reset_index()
df1
# Out:
#              STATE/UT  MURDER  ATTEMPT TO MURDER  \
# 0       A & N ISLANDS     160                 65
# 1      ANDHRA PRADESH   31756              22420
# 2   ARUNACHAL PRADESH     841                417
# 3               ASSAM   15432               5662
# 4               BIHAR   41245              40919
# 5          CHANDIGARH     243                301
# 6        CHHATTISGARH   12060               7910
# 7        D & N HAVELI     108                 31
# 8         DAMAN & DIU      68                 38
# 9            DELHI UT    6205               5277
# 10                GOA     487                269
# 11            GUJARAT   13775               6112
# 12            HARYANA   10471               7434
# 13   HIMACHAL PRADESH    1454                835
# 14    JAMMU & KASHMIR    6304              10303
# 15          JHARKHAND   19060              12270
# 16          KARNATAKA   19937              18512
# 17             KERALA    4733               5327
# ...

# %% [markdown]
# Now we have all the States/UT with their sum of total crimes present under the column Total IPC crimes. We will use this dataset to create the clusters as needed.

# %% [markdown]
# ### Standardising the data for clustering

# %%
x=df1.drop(columns='STATE/UT')
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
xscaled=scalar.fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
x1 = pca.fit_transform(x)

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3, random_state=65)

y = model.fit_predict(x1) 
y
# Out:
# array([0, 1, 0, 2, 1, 0, 2, 0, 0, 2, 0, 1, 2, 0, 0, 2, 1, 1, 0, 1, 1, 0,
#        0, 0, 0, 2, 0, 2, 1, 0, 1, 0, 1, 0, 2])

# %%
from sklearn.metrics import silhouette_score
silhouette_score(x,y)
# Out:
# 0.6672631992248999

# %% [markdown]
# We have a silhouette score of 67%

# %%
df1['sensitivity'] = model.labels_
df1
# Out:
#              STATE/UT  MURDER  ATTEMPT TO MURDER  \
# 0       A & N ISLANDS     160                 65
# 1      ANDHRA PRADESH   31756              22420
# 2   ARUNACHAL PRADESH     841                417
# 3               ASSAM   15432               5662
# 4               BIHAR   41245              40919
# 5          CHANDIGARH     243                301
# 6        CHHATTISGARH   12060               7910
# 7        D & N HAVELI     108                 31
# 8         DAMAN & DIU      68                 38
# 9            DELHI UT    6205               5277
# 10                GOA     487                269
# 11            GUJARAT   13775               6112
# 12            HARYANA   10471               7434
# 13   HIMACHAL PRADESH    1454                835
# 14    JAMMU & KASHMIR    6304              10303
# 15          JHARKHAND   19060              12270
# 16          KARNATAKA   19937              18512
# 17             KERALA    4733               5327
# ...

# %% [markdown]
# We have added the column sensitivity to tell which state comes in which sensitivity area. And from careful analysis we have came to the conclusion that peaceful states are with 0 sesitivity, moderate states with 2 and sensitive states as 1

# %% [markdown]
# # 4.2) Create DataFrame for each cluster that shows data according to the areas.

# %%
peaceful_states = df1[df1['sensitivity'] == 0]
sensitive_states = df1[df1['sensitivity'] == 1]
moderate_states =df1[df1['sensitivity'] == 2]

# %%
peaceful_states
# Out:
#              STATE/UT  MURDER  ATTEMPT TO MURDER  \
# 0       A & N ISLANDS     160                 65
# 2   ARUNACHAL PRADESH     841                417
# 5          CHANDIGARH     243                301
# 7        D & N HAVELI     108                 31
# 8         DAMAN & DIU      68                 38
# 10                GOA     487                269
# 13   HIMACHAL PRADESH    1454                835
# 14    JAMMU & KASHMIR    6304              10303
# 18        LAKSHADWEEP       3                  6
# 21            MANIPUR    1955               3536
# 22          MEGHALAYA    1730                601
# 23            MIZORAM     403                258
# 24           NAGALAND    1038                464
# 26         PUDUCHERRY     357                343
# 29             SIKKIM     166                111
# 31            TRIPURA    2022                681
# 33        UTTARAKHAND    2948               2627
#
#     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
moderate_states
# Out:
#         STATE/UT  MURDER  ATTEMPT TO MURDER  \
# 3          ASSAM   15432               5662
# 6   CHHATTISGARH   12060               7910
# 9       DELHI UT    6205               5277
# 12       HARYANA   10471               7434
# 15     JHARKHAND   19060              12270
# 25        ODISHA   14453              15652
# 27        PUNJAB    9493              10397
# 34   WEST BENGAL   21056              14693
#
#     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER   RAPE  CUSTODIAL RAPE  \
# 3                                         718  16178               5
# 6                                         348  11838               0
# 9                                         883   6424               0
# 12                                        857   6410               1
# 15                                       1231   9159               5
# 25                                        698  11430               0
# 27                                       1558   5459               1
# ...

# %%
sensitive_states
# Out:
#           STATE/UT  MURDER  ATTEMPT TO MURDER  \
# 1   ANDHRA PRADESH   31756              22420
# 4            BIHAR   41245              40919
# 11         GUJARAT   13775               6112
# 16       KARNATAKA   19937              18512
# 17          KERALA    4733               5327
# 19  MADHYA PRADESH   28399              29458
# 20     MAHARASHTRA   32767              20589
# 28       RAJASTHAN   15844              21342
# 30      TAMIL NADU   20127              26597
# 32   UTTAR PRADESH   65443              60520
#
#     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER   RAPE  CUSTODIAL RAPE  \
# 1                                        1763  13479               2
# 4                                        3672  13124               2
# 11                                        430   4249               0
# 16                                        857   5174               2
# 17                                       1897   7447               0
# ...

# %% [markdown]
# # 4.3 ) Analyse your clusters and prepare a report that explains all your observations.

# %%
sensitive_states['STATE/UT'].value_counts()
# Out:
# ANDHRA PRADESH    1
# BIHAR             1
# GUJARAT           1
# KARNATAKA         1
# KERALA            1
# MADHYA PRADESH    1
# MAHARASHTRA       1
# RAJASTHAN         1
# TAMIL NADU        1
# UTTAR PRADESH     1
# Name: STATE/UT, dtype: int64

# %%
peaceful_states['STATE/UT'].value_counts()
# Out:
# A & N ISLANDS        1
# MANIPUR              1
# TRIPURA              1
# SIKKIM               1
# PUDUCHERRY           1
# NAGALAND             1
# MIZORAM              1
# MEGHALAYA            1
# LAKSHADWEEP          1
# ARUNACHAL PRADESH    1
# JAMMU & KASHMIR      1
# HIMACHAL PRADESH     1
# GOA                  1
# DAMAN & DIU          1
# D & N HAVELI         1
# CHANDIGARH           1
# UTTARAKHAND          1
# Name: STATE/UT, dtype: int64

# %%
moderate_states['STATE/UT'].value_counts()
# Out:
# ASSAM           1
# CHHATTISGARH    1
# DELHI UT        1
# HARYANA         1
# JHARKHAND       1
# ODISHA          1
# PUNJAB          1
# WEST BENGAL     1
# Name: STATE/UT, dtype: int64

# %% [markdown]
# ### Correlation Map to check for causes and correlation between factors

# %%
plt.figure(figsize=(25,20))
sns.heatmap(sensitive_states.corr(),annot=True, mask=np.tril(sensitive_states.corr()))
# Out:
# <AxesSubplot:>

# %%
sensitive_states.corr()
# Out:
#                                                       MURDER  \
# MURDER                                              1.000000
# ATTEMPT TO MURDER                                   0.932278
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER           0.838411
# RAPE                                                0.413393
# CUSTODIAL RAPE                                      0.649019
# OTHER RAPE                                          0.413331
# KIDNAPPING & ABDUCTION                              0.844294
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         0.795823
# KIDNAPPING AND ABDUCTION OF OTHERS                  0.715269
# DACOITY                                             0.517122
# PREPARATION AND ASSEMBLY FOR DACOITY                0.002006
# ROBBERY                                             0.670264
# BURGLARY                                            0.147520
# THEFT                                               0.431780
# ...

# %% [markdown]
# This leads you to notice a few highly connected factors:
#
# CRIME AND ATTEMPT TO CRIME: 0.932278; CUSTODIAL CRIME AND RAPE: 0.649019
# Attack and Rape of Women with the Intention to Disrespect Their Modesty: 0.813716
# WOMEN'S RAPE AND INSULT TO MODESTY: 0.565460;
# IPC CRIMES TOTAL AND RAPE: 0.721107

# %% [markdown]
# Analysis of the aforementioned information reveals that:
#
# **Northeast region and Union territories** are home to the majority of the states in **peaceful areas**. The state's tiny size and low population density could be the cause of this.
#
# Furthermore, the states in the **Sensitive areas** are among the **largest states in India** in terms of land area. They have a large population as well.
#
# In **Moderate Areas** there is only one UT existing which is Delhi (the capital of India) and only state from northeastern area Assam.
#
# **Many factors**, including drug misuse, the pervasiveness of gang culture, low literacy rates, prejudice, human trafficking, and weak government law enforcement, can lead to higher crime rates. The high number of rape cases may be significantly attributed to gender disparity.
#
#
# Conclusions about the degree of safety in each Indian state:
# **Most Unsafe State**: Madhya Pradesh emerges as the most unsafe state, reporting a total of 2,413,770 IPC crimes and 5,139,445 overall crimes.
# **Safest State**: Conversely, with only 743 IPC crimes and 1,607 total crimes recorded, Lakshadweep is notable for being the safest state in India.
#
# How might one **minimise criminal activity?**
# It takes a diversified strategy with an emphasis on multiple crucial areas to reduce crime. The following tactics are some that can help lower crime:
#
#
# Increasing Literacy Rates: Reducing crime rates in a state or nation is contingent upon raising literacy rates.
#
# Encouraging Civil Rights Awareness: It's important to raise awareness of civil rights. Being aware of one's rights gives people the ability to stop wrongdoing.
#
# Sturdying Government Institutions: Sturdy government agencies are necessary to act decisively and keep future crises under control.
#
# Taking Action Against Gender Inequality: Reducing instances of rape requires a strong focus on gender inequality. Together with public education campaigns, the government should implement comprehensive policies and laws.
#
#
# Employment Opportunities: Since unemployment may be a contributing factor to crime, it is imperative to combat it. Policies and programmes implemented by the government with the goal of creating jobs are essential.
#
# Youth Engagement Programmes: Enacting initiatives that empower and include young people, giving them positive ways to channel their skills and energies, can help prevent involvement in criminal activity.
#
# Substance misuse Prevention: Programmes that aim to stop substance misuse can lessen the number of crimes associated with addiction and drug abuse.
#
# Social Support Systems: Addressing underlying issues that may give rise to criminal behaviour can be accomplished by strengthening social support systems, which include mental health services and rehabilitation programmes.
#
#
# Technological Solutions: Law enforcement capacities can be improved by utilising technology for crime mapping, surveillance, and predictive policing.
#
# International cooperation is working together to combat transnational crimes and exchange best practices in crime prevention with other nations and international organisations.
#
# Education Reforms: Putting values, ethics, and conflict resolution front and centre in the classroom can help build a community that abides by the law more closely.
#
# Programmes for Restorative Justice: Rather than concentrating just on punitive measures, restorative justice programmes emphasise rehabilitation and reconciliation.

# %% [markdown]
# # 4.4) Capstone project overall story in your own words. Min 1000 words.

# %% [markdown]
# We were charged with examining crime statistics in India for our capstone project, with a particular emphasis on districts and states/union territories (UT). We were able to utilise 11 files from Datatrained Academy for our investigation, and the dataset encompassed the years 2001 to 2012.
#
# We were instructed to gather more data from whatever source—whether manually or by webscraping—because the available data was insufficient. There were four stages of the project.
#
#
# **PHASE 1** involved gathering the data and storing it in a fresh file. The information that we required to gather was:
#
# 1. The population of each state.
#
# 2. Each state's literacy rate
#
# 3. Every state's area.
#
#
#
#  We were given the task of performing a thorough analysis of the data at the STATE/UT level during **PHASE 2** of the project. Many analytical techniques were used, including analysing the relationship between total crimes and the literacy rate, looking into the relationship between population and total crime, studying the total crime rate year over year, and analysing the correlation between the types of crimes and each state in relation to the literacy rate. As the final step in Phase 2, we conducted in-depth analyses of every state and created complete crime reports using the knowledge we gathered from various data sources.
#
# In the next stage, **PHASE 3**, we turned our attention to running SQL commands. Our specific assignment was to create SQL queries that would allow us to work with the eleven files that the Datatrained Academy had provided in different ways. The primary goal of this stage was entering data into a specified table and then extracting information based on predetermined criteria. At the end of this phase, we used visualisation techniques in addition to storing pertinent data in DataFrames to improve our analytical skills.
#
# In **PHASE 4** of our research, we used unsupervised machine learning methods to explore the field of clustering. Based on their crime statistics, the main goal was to group the data into discrete clusters that represented sensitive, moderate, and quiet zones. The initial phase entailed consolidating the data by state, followed by the use of the KMeans method, resulting in the partitioning of the data into three segments: Cluster 0 (moderate), Cluster 1 (sensitive), and Cluster 2 (moderate).
#
# The overall number of offences in each location was assessed in order to determine the classification criteria. The lowest frequency of total crimAfter a thorough investigation, we discovered a number of **correlated factors** that provide insight into the ways in which distinct states are categorised within their respective clusters. Our study examined the variables affecting the overall number of IPC offences, looking at how the state's location, population, literacy rates, and educational attainment all affected how these crimes clustered. Our research revealed the various kinds and intensities of crimes that occur in various areas**, offering important new perspectives on the intricate dynamics of crime distribution.
#
#  We also explored **methods and initiatives targeted at reducing the crime rate** and total frequency of criminal activity. We talked about a wide range of methods and strategies that may be used to deal with the complicated problem of crime, looking into ways to be proactive in our intervention and creating a safer social milieu.
# es was found in peaceful areas, whilst the average level of total crimes was found in moderate areas. Conversely, areas that are considered sensitive were shown to be the least safe, as they have a significantly higher rate of overall criminal activity.
#
#  After segmenting the data, we meticulously developed a specific dataframe for every cluster. Based on their respective total crime rates, **Madhya Pradesh as the most unsafe state and Lakshadweep as the safest state** were the conclusions drawn from our in-depth investigation.
#
#
# After a thorough investigation, we discovered a number of **correlated factors** that provide insight into the ways in which distinct states are categorised within their respective clusters. Our study examined the variables affecting the overall number of IPC offences, looking at how the state's location, population, literacy rates, and educational attainment all affected how these crimes clustered. Our research revealed the various kinds and intensities of crimes that occur in various areas**, offering important new perspectives on the intricate dynamics of crime distribution.
#
#  We also explored **methods and initiatives targeted at reducing the crime rate** and total frequency of criminal activity. We talked about a wide range of methods and strategies that may be used to deal with the complicated problem of crime, looking into ways to be proactive in our intervention and creating a safer social milieu.
